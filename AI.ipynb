# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/<DIR>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT
# Out:
# /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT

# %%
from getpass import getpass
user = getpass('Username: ') # Nhập username trên Github
password = getpass('Password: ') # Nhập password
repo = lesonlhld/AI-ass2

# !git clone https://{user}:{password}@github.com/{repo}

# %%
# %cd /content/drive/MyDrive/<DIR>/<REPO>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2
# Out:
# /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2

# %%
# !git config --global user.name lesonlhld #Username
# !git config --global user.email lesonlhld@gmail.com #Email

# %%
# !python testcase.py
# !git add .
# !git commit -a -m "Updating best results"
# !git push -u origin master
# Out:
# Testcase 1
# Time run: 3.1536502838134766
# Current Minimize: 48.56057183091434
# Previous Minimize: 5.868378984226283
# ================================
# Testcase 2
# Time run: 7.5942511558532715
# Current Minimize: 100.55927833281038
# Previous Minimize: 86.2967311887966
# ================================
# Testcase 3
# Time run: 1.132756233215332
# Current Minimize: 58.45149741080095
# Previous Minimize: 58.45149741080094
# ================================
# Testcase 4
# Time run: 1.4967949390411377
# Current Minimize: 18.06343204913567
# Previous Minimize: 9.906766793742023
# ================================
# Testcase 5
# Time run: 3.4643800258636475
# Current Minimize: 122.0954586409639
# Previous Minimize: 48.07901663314674
# ================================
# Testcase 6
# Time run: 32.40443181991577
# Current Minimize: 650.5902588432936
# Previous Minimize: 559.8228393329704
# ================================
# Testcase 7
# Time run: 8.022791385650635
# Current Minimize: 260.1824673744048
# Previous Minimize: 189.83308896138627
# ================================
# Testcase 8
# Time run: 8.796574115753174
# Current Minimize: 449.7513340998229
# Previous Minimize: 397.6850364911632
# ================================
# Testcase 9
# Time run: 6.481581449508667
# Current Minimize: 280.9103743908671
# Previous Minimize: 246.07497810053354
# ================================
# Testcase 10
# Traceback (most recent call last):
#   File "testcase.py", line 163, in <module>
#   File "/content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 262, in assign
#     output = makeSolution(deplot, orders, numOfSalesman)
#   File "/content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 115, in makeSolution
#     deplot, orders, cluster, minimize)
#   File "/content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 188, in makeBestSolution
#     next_order = swap(solution, sman)
#   File "/content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 146, in swap
#     key1, key2 = np.random.choice(list(cluster[nsman]), 2, replace=False)
#   File "mtrand.pyx", line 936, in numpy.random.mtrand.RandomState.choice
#   File "<__array_function__ internals>", line 6, in prod
#   File "/usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py", line 3000, in prod
#     keepdims=keepdims, initial=initial, where=where)
#   File "/usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# [master 0ac5022] Updating best results
#  3 files changed, 50 insertions(+), 3 deletions(-)
#  rewrite AI.ipynb (90%)
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (10/10), 2.42 KiB | 495.00 KiB/s, done.
# Total 10 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 3 local objects.
# To https://github.com/lesonlhld/AI-ass2
#    4ed76a4..0ac5022  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
