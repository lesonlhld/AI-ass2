# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/<DIR>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT
# Out:
# /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT

# %%
from getpass import getpass
user = getpass('Username: ') # Nhập username trên Github
password = getpass('Password: ') # Nhập password
repo = lesonlhld/AI-ass2

# !git clone https://{user}:{password}@github.com/{repo}

# %%
# %cd /content/drive/MyDrive/<DIR>/<REPO>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2
# Out:
# /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2

# %%
# !git config --global user.name lesonlhld #Username
# !git config --global user.email lesonlhld@gmail.com #Email

# %%
# !python testcase.py
# !git add .
# !git commit -a -m "Updating best results"
# !git push -u origin master
# Out:
# Testcase 1
# Time run: 1.5188419818878174
# Current Minimize: 14.212401570791279
# Previous Minimize: 2.9341894921131413
# ================================
# Testcase 2
# Time run: 2.8508641719818115
# Current Minimize: 59.972222184867064
# Previous Minimize: 43.1483655943983
# ================================
# Testcase 3
# Time run: 3.1877682209014893
# Current Minimize: 42.22243514964668
# Previous Minimize: 29.22574870540047
# ================================
# Testcase 4
# Traceback (most recent call last):
#   File "testcase.py", line 163, in <module>
#   File "/content/drive/My Drive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 262, in assign
#     output = makeSolution(deplot, orders, numOfSalesman)
#   File "/content/drive/My Drive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 115, in makeSolution
#     deplot, orders, cluster, minimize)
#   File "/content/drive/My Drive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 188, in makeBestSolution
#     next_order = swap(solution, sman)
#   File "/content/drive/My Drive/Bách Khoa/Đề/NMTTNT/AI-ass2/assignment2.py", line 146, in swap
#     key1, key2 = np.random.choice(list(cluster[nsman]), 2, replace=False)
# KeyboardInterrupt
# [master 7bf17b9] Updating best results
#  2 files changed, 18 insertions(+), 4 deletions(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.63 KiB | 555.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/lesonlhld/AI-ass2
#    0ac5022..7bf17b9  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
