# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/<DIR>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT

# %%
from getpass import getpass
user = getpass('Username: ') # Nhập username trên Github
password = getpass('Password: ') # Nhập password
repo = lesonlhld/AI-ass2

# !git clone https://{user}:{password}@github.com/{repo}

# %%
# %cd /content/drive/MyDrive/<DIR>/<REPO>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2

# %%
# !git config --global user.name lesonlhld #Username
# !git config --global user.email lesonlhld@gmail.com #Email

# %%
# !python testcase.py
# !git add .
# !git commit -a -m "Updating best results"
# !git push -u origin master
# Out:
# Testcase 1
# Time run: 2.762596368789673
# Current Minimize: 8.262477614399913
# Previous Minimize: 2.9341894921131413
# ================================
# Testcase 2
# Time run: 5.1519083976745605
# Current Minimize: 60.5099686201893
# Previous Minimize: 43.1483655943983
# ================================
# Testcase 3
# Time run: 2.3184289932250977
# Current Minimize: 33.21969201275189
# Previous Minimize: 35.666900343292866
# ================================
# Testcase 4
# Time run: 2.472649335861206
# Current Minimize: 8.690220976128991
# Previous Minimize: 4.953383396871011
# ================================
# Testcase 5
# Time run: 4.484208345413208
# Current Minimize: 50.58715502757505
# Previous Minimize: 24.03950831657337
# ================================
# Testcase 6
# Time run: 12.727570533752441
# Current Minimize: 326.02423510799554
# Previous Minimize: 304.86031640000743
# ================================
# Testcase 7
# Time run: 5.471498012542725
# Current Minimize: 161.0021064755355
# Previous Minimize: 94.91654448069313
# ================================
# Testcase 8
# Time run: 8.226250410079956
# Current Minimize: 225.3380873307897
# Previous Minimize: 198.8425182455816
# ================================
# Testcase 9
# Time run: 4.622828245162964
# Current Minimize: 150.0529471685289
# Previous Minimize: 123.91953910169961
# ================================
# Testcase 10
# Time run: 7.6251537799835205
# Current Minimize: 173.81211618174314
# Previous Minimize: 98.54276708132028
# ================================
# Testcase 11
# Time run: 28.126877784729004
# Current Minimize: 615.4812409038461
# Previous Minimize: 593.2406238553974
# ================================
# Testcase 12
# Time run: 19.519787311553955
# Current Minimize: 431.5561005980408
# Previous Minimize: 377.9057207254967
# ================================
# Testcase 13
# Time run: 12.616891622543335
# Current Minimize: 320.07822918561294
# Previous Minimize: 264.4703417512512
# ================================
# Testcase 14
# Time run: 13.771896123886108
# Current Minimize: 508.8371419213606
# Previous Minimize: 542.2149653956952
# ================================
# Testcase 15
# Time run: 21.927804470062256
# Current Minimize: 491.93587580292706
# Previous Minimize: 436.58911113160553
# ================================
# Testcase 16
# Time run: 16.671380043029785
# Current Minimize: 1268.955716361588
# Previous Minimize: 1165.9705680855611
# ================================
# Testcase 17
# Time run: 36.39195370674133
# Current Minimize: 770.1623960934846
# Previous Minimize: 760.9565095497768
# ================================
# Testcase 18
# Time run: 13.646732568740845
# Current Minimize: 1445.2287495954406
# Previous Minimize: 970.377152220932
# ================================
# Testcase 19
# Time run: 10.742352724075317
# Current Minimize: 643.9109221021516
# Previous Minimize: 655.1287448653314
# ================================
# Testcase 20
# Time run: 13.68844723701477
# Current Minimize: 884.7422224295962
# Previous Minimize: 860.3374437933933
# ================================
# Testcase 21
# Time run: 12.261584520339966
# Current Minimize: 946.2849976298579
# Previous Minimize: 926.4133311445233
# ================================
# Testcase 22
# Time run: 43.53613615036011
# Current Minimize: 2093.6461499996344
# Previous Minimize: 1745.9014214474619
# ================================
# Testcase 23
# Time run: 10.359986305236816
# Current Minimize: 837.8173287029834
# Previous Minimize: 420.1683978446208
# ================================
# Testcase 24
# Time run: 306.4898633956909
# Current Minimize: 7252.788268144234
# Previous Minimize: 5558.507488081246
# ================================
# Testcase 25
# Time run: 72.54135179519653
# Current Minimize: 4489.63531269948
# Previous Minimize: 4049.040296362601
# ================================
# ########################################################################
# Testcase 1
# Time run: 2.2153782844543457
# Current Minimize: 14.551412496726165
# Previous Minimize: 2.9341894921131413
# ================================
# Testcase 2
# Time run: 3.8034098148345947
# Current Minimize: 85.26241846085249
# Previous Minimize: 43.1483655943983
# ================================
# Testcase 3
# Time run: 3.862393379211426
# Current Minimize: 31.54376053522961
# Previous Minimize: 33.21969201275189
# ================================
# Testcase 4
# Time run: 2.472707748413086
# Current Minimize: 14.538329391529707
# Previous Minimize: 4.953383396871011
# ================================
# Testcase 5
# Time run: 3.4416162967681885
# Current Minimize: 52.87390385847922
# Previous Minimize: 24.03950831657337
# ================================
# Testcase 6
# Time run: 19.997488021850586
# Current Minimize: 311.71252511976314
# Previous Minimize: 304.86031640000743
# ================================
# Testcase 7
# Time run: 9.50635552406311
# Current Minimize: 142.27024602709173
# Previous Minimize: 94.91654448069313
# ================================
# Testcase 8
# Time run: 14.417519569396973
# Current Minimize: 201.34637165310264
# Previous Minimize: 198.8425182455816
# ================================
# Testcase 9
# Time run: 7.698170900344849
# Current Minimize: 165.96892930380102
# Previous Minimize: 123.91953910169961
# ================================
# Testcase 10
# Time run: 6.434992074966431
# Current Minimize: 130.98412474352023
# Previous Minimize: 98.54276708132028
# ================================
# Testcase 11
# Time run: 42.89946103096008
# Current Minimize: 566.9424626289506
# Previous Minimize: 593.2406238553974
# ================================
# Testcase 12
# Time run: 25.429155588150024
# Current Minimize: 403.2540284367231
# Previous Minimize: 377.9057207254967
# ================================
# Testcase 13
# Time run: 13.217679738998413
# Current Minimize: 343.9093399274225
# Previous Minimize: 264.4703417512512
# ================================
# Testcase 14
# Time run: 9.809465646743774
# Current Minimize: 559.6547708544055
# Previous Minimize: 508.8371419213606
# ================================
# Testcase 15
# Time run: 13.503244400024414
# Current Minimize: 498.18462965553954
# Previous Minimize: 436.58911113160553
# ================================
# Testcase 16
# Time run: 17.54261040687561
# Current Minimize: 1356.845398684418
# Previous Minimize: 1165.9705680855611
# ================================
# Testcase 17
# Time run: 51.61807823181152
# Current Minimize: 825.6262675096283
# Previous Minimize: 760.9565095497768
# ================================
# Testcase 18
# Time run: 12.639631986618042
# Current Minimize: 1346.4166848515413
# Previous Minimize: 970.377152220932
# ================================
# Testcase 19
# Time run: 13.813227891921997
# Current Minimize: 786.7984514500702
# Previous Minimize: 643.9109221021516
# ================================
# Testcase 20
# Time run: 8.64774775505066
# Current Minimize: 740.7021155347243
# Previous Minimize: 860.3374437933933
# ================================
# Testcase 21
# Time run: 13.55199384689331
# Current Minimize: 858.7090521868125
# Previous Minimize: 926.4133311445233
# ================================
# Testcase 22
# Time run: 22.803802490234375
# Current Minimize: 1725.2815374468853
# Previous Minimize: 1745.9014214474619
# ================================
# Testcase 23
# Time run: 7.091250419616699
# Current Minimize: 702.7122499621929
# Previous Minimize: 420.1683978446208
# ================================
# Testcase 24
# Time run: 310.5689232349396
# Current Minimize: 7099.637932430081
# Previous Minimize: 5558.507488081246
# ================================
# Testcase 25
