# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/<DIR>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT
# Out:
# /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT

# %%
from getpass import getpass
user = getpass('Username: ') # Nhập username trên Github
password = getpass('Password: ') # Nhập password
repo = lesonlhld/AI-ass2

# !git clone https://{user}:{password}@github.com/{repo}

# %%
# %cd /content/drive/MyDrive/<DIR>/<REPO>
# %cd /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2
# Out:
# /content/drive/MyDrive/Bách Khoa/Đề/NMTTNT/AI-ass2

# %%
# !git config --global user.name lesonlhld #Username
# !git config --global user.email lesonlhld@gmail.com #Email

# %%
# !python testcase.py
# !git add .
# !git commit -a -m "Updating best results"
# !git push -u origin master
# Out:
# Testcase 1
# Time run: 1.5970702171325684
# Current Minimize: 32.347787878728965
# Previous Minimize: 5.868378984226283
# ...
# Testcase 2
# Time run: 9.198129653930664
# Current Minimize: 129.9967166050451
# Previous Minimize: 80.57105025146873
# ...
# Testcase 3
# Time run: 3.811656951904297
# Current Minimize: 74.03143026944083
# Previous Minimize: 58.45149741080094
# ...
# Testcase 4
# Time run: 1.8706927299499512
# Current Minimize: 23.090488596045617
# Previous Minimize: 9.906766793742023
# ...
# Testcase 5
# Time run: 5.266340494155884
# Current Minimize: 85.09100305050711
# Previous Minimize: 48.07901663314674
# ...
# Testcase 6
# Time run: 17.17769956588745
# Current Minimize: 655.5293681964692
# Previous Minimize: 512.3048908163082
# ...
# Testcase 7
# Time run: 4.203397512435913
# Current Minimize: 299.13751600152506
# Previous Minimize: 189.83308896138627
# ...
# Testcase 8
# Time run: 5.884577989578247
# Current Minimize: 526.1394226578952
# Previous Minimize: 397.6850364911632
# ...
# Testcase 9
# ...
